# %% [markdown]
# ### Web-scraping data from the PA department of health and converting to pandas DF

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# list of metrics
metrics = [
    'mich-01-fetal-mortality-rate-20-weeks-gestation',
    'mich-02-infant-mortality-rate-lhi',
    'mich-03-child-and-adolescent-death-rate-aged-1-to-19',
    'mich-06-percent-of-low-risk-no-prior-birth-females-giving-birth-by-cesarean',
    'mich-07-percent-of-live-births-which-are-preterm',
    'mich-08-percent-of-pregnant-females-with-early-and-adequate-prenatal-care',
    'mich-10-percent-of-females-giving-birth-who-did-not-smoke-during-pregnancy',
    'mich-13-percent-of-mothers-with-a-healthy-weight-before-giving-birth'
]

labelsFormal = ['MICH-01', 'MICH-02', 'MICH-03', 'MICH-06', 'MICH-07', 'MICH-08', 'MICH-10', 'MICH-13']

# %%
all_metrics = pd.DataFrame()
all_vars = []
for i, m in enumerate(metrics): 
    url = 'https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/'+m+'.aspx'
    print(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    table_info = soup.find_all('script')
    data_Str = table_info[15].prettify()
    dataStart = data_Str.find('Pennsylvania')-2
    dataEnd = data_Str.find('container')-3
    dataString = data_Str[dataStart:dataEnd]
    dataList = eval(dataString)
    dataDF = pd.DataFrame(dataList).T
    varnames = ['2011-2015', '2012-2016', '2013-2017', '2014-2018', '2015-2019', 'MetGoal']
    m_specific_vars = [labelsFormal[i]+'_'+var for var in varnames]
    all_vars = all_vars+m_specific_vars
    dataDF.columns = ['County'+str(i)]+m_specific_vars
    
    all_metrics = pd.concat([all_metrics, dataDF], axis="columns")

keep_vars = ['County0']+all_vars

all_metrics = all_metrics[keep_vars]
all_metrics
# Out:
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-01-fetal-mortality-rate-20-weeks-gestation.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-02-infant-mortality-rate-lhi.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-03-child-and-adolescent-death-rate-aged-1-to-19.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-06-percent-of-low-risk-no-prior-birth-females-giving-birth-by-cesarean.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-07-percent-of-live-births-which-are-preterm.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-08-percent-of-pregnant-females-with-early-and-adequate-prenatal-care.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-10-percent-of-females-giving-birth-who-did-not-smoke-during-pregnancy.aspx
# https://www.health.pa.gov/topics/HealthStatistics/HealthyPeople/Documents/current/county/mich-13-percent-of-mothers-with-a-healthy-weight-before-giving-birth.aspx
#          County0 MICH-01_2011-2015 MICH-01_2012-2016 MICH-01_2013-2017  \
# 0   Pennsylvania               6.5               6.4               6.2
# 1          Adams               3.8               3.7               4.8
# 2      Allegheny               6.1               6.1               6.1
# 3      Armstrong               4.6               5.7               5.8
# 4         Beaver               7.2               6.8               6.6
# ..           ...               ...               ...               ...
# 63    Washington               4.5               4.0               4.8
# 64         Wayne               DSU               DSU               DSU
# 65  Westmoreland               4.6               4.7               4.4
# 66       Wyoming               DSU               DSU               DSU
# 67          York               5.4               5.5               5.5
#
#    MICH-01_2014-2018 MICH-01_2015-2019 MICH-01_MetGoal MICH-02_2011-2015  \
# 0                6.1               6.0              No               6.5
# 1                5.7               4.7             Yes               3.8
# 2                5.9               6.0              No               6.1
# 3                4.3               6.3              No               4.6
# 4                6.4               7.2              No               7.2
# ..               ...               ...             ...               ...
# 63               4.7               5.0             Yes               4.5
# 64               DSU               DSU             DSU               DSU
# 65               4.8               4.8             Yes               4.6
# 66               DSU               DSU             DSU               DSU
# 67               5.6               5.4              No               5.4
#
#    MICH-02_2012-2016 MICH-02_2013-2017  ... MICH-10_2013-2017  \
# 0                6.4               6.2  ...               6.2
# 1                3.7               4.8  ...               4.8
# 2                6.1               6.1  ...               6.1
# 3                5.7               5.8  ...               5.8
# 4                6.8               6.6  ...               6.6
# ..               ...               ...  ...               ...
# 63               4.0               4.8  ...               4.8
# 64               DSU               DSU  ...               DSU
# 65               4.7               4.4  ...               4.4
# 66               DSU               DSU  ...               DSU
# 67               5.5               5.5  ...               5.5
#
#    MICH-10_2014-2018 MICH-10_2015-2019 MICH-10_MetGoal MICH-13_2011-2015  \
# 0                6.1               6.0              No               6.5
# 1                5.7               4.7             Yes               3.8
# 2                5.9               6.0              No               6.1
# 3                4.3               6.3              No               4.6
# 4                6.4               7.2              No               7.2
# ..               ...               ...             ...               ...
# 63               4.7               5.0             Yes               4.5
# 64               DSU               DSU             DSU               DSU
# 65               4.8               4.8             Yes               4.6
# 66               DSU               DSU             DSU               DSU
# 67               5.6               5.4              No               5.4
#
#    MICH-13_2012-2016 MICH-13_2013-2017 MICH-13_2014-2018 MICH-13_2015-2019  \
# 0                6.4               6.2               6.1               6.0
# 1                3.7               4.8               5.7               4.7
# 2                6.1               6.1               5.9               6.0
# 3                5.7               5.8               4.3               6.3
# 4                6.8               6.6               6.4               7.2
# ..               ...               ...               ...               ...
# 63               4.0               4.8               4.7               5.0
# 64               DSU               DSU               DSU               DSU
# 65               4.7               4.4               4.8               4.8
# 66               DSU               DSU               DSU               DSU
# 67               5.5               5.5               5.6               5.4
#
#    MICH-13_MetGoal
# 0               No
# 1              Yes
# 2               No
# 3               No
# 4               No
# ..             ...
# 63             Yes
# 64             DSU
# 65             Yes
# 66             DSU
# 67              No
#
# [68 rows x 49 columns]

# %%
all_metrics.shape
# Out:
# (68, 49)

# %%
all_metrics.to_csv('PAHealth_MaternalChildHealth_20221114.csv')

# %% [markdown]
# ### Hospital Data

# %%
url = 'https://www.ahd.com/states/hospital_PA.html'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-US">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>American Hospital Directory - Abuse</title>
# <meta content="The American Hospital Directory provides operational data, financial information, utilization statistics and other benchmarks for acute care hospitals." name="description">
# <meta content="hospital, hospitals, hospital data, hospital performance, health care,  quality outcomes, clinical quality measurements, HCFA, CMS, MedPAR, HEDIS, AMA, NCQA, JCAHO, HFMA, DRG, information, statistics, benchmark, benchmarks, benchmarking" name="keywords"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <base href="https://www.ahd.com/" id="myBaseId"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/touch-icon-iphone.png" rel="apple-touch-icon">
# <link href="/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/styles/ahd2010.73.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/jquery.fancybox-2.1.5.css?v=73" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
# <script src="/core/js/autosuggest.js?33" type="text/javascript"></script>
# <script src="/js/jquery.ba-resize.min.js" type="text/javascript"></script>
# <script src="/js/jquery.fancybox-2.1.5.pack.js" type="text/javascript"></script>
# <script src="/js/jScrollTouch.js" type="text/javascript"></script>
# <script src="/js/ahd_tools.44.js" type="text/javascript"></script>
# </link></meta></head>
# <body id="body" topmargin="0">
# <div id="wrapper">
# <div id="main_content">
# <div id="header">
# <div id="logo">
# <a href="/"><span class="sprite ahdlogo_220"> </span></a>
# </div>
# <div id="navigation_bar">
# <div id="nav_left">
#
#                     </div>
# <div id="nav_wrap">
# <div class="nav_row" style="text-align: right;">
# <ul id="topnav">
# </ul>
# </div>
# <form action="/states/hospital_PA.html" method="post" name="NAVLOGINFORM">
# <div id="loginform">
# <input id="LES" name="LES" type="hidden" value="1668800934"/>
# <div style="text-align: right;">
# <div>
# <label for="LOGIN_UNAME">User Name:</label>
# <input accesskey="u" id="LOGIN_UNAME" name="LOGIN_UNAME" size="12" spellcheck="false" type="text"/>
# </div>
# <div>
# <label for="LOGIN_PWD">Password:</label>
# <input id="LOGIN_PWD" name="LOGIN_PWD" size="12" type="password"/>
# </div>
# </div>
# </div>
# <div class="nav_row">
# <div class="nav_spacer"> </div>
# <div class="navbuttons"><a href="/">Home</a></div>
# <div class="navbuttons"><a href="/search.php">FREE Search</a></div>
# <div class="navbuttons"><a href="/faq.html" title="Answers to Frequently Asked Questions">FAQs</a></div>
# <div class="navbuttons"><a href="/data_sources.html" title="Current Data Sources">Sources</a></div>
# <div class="navbuttons"><a href="/enhancements.html" title="Recent Enhancements">Updates</a></div>
# <div class="navbuttons_ordernow"><a href="/ordernow.html">Order Info</a></div>
# <div class="nav_open_spacer"> </div>
# <div class="navbuttons"><input id="login" type="submit" value="Login"/></div>
# <div class="nav_spacer"> </div>
# </div>
# </form>
# </div>
# <div id="nav_right">
#
#                     </div>
# </div>
# <div style="clear: both; height: 0px;"> </div>
# </div>
# <div id="main">
# <div id="rpt_header">
# <div></div>
# <div>
# <h2 id="page_title">Abuse</h2>
# </div>
# </div>
# <div class="subcontent"><p>Your access to AHD.com has been suspended for suspected abuse of our terms and conditions of use.</p>
# <p>The use of an automated process (which is prohibited under our terms of service) or high volumes of usage from one location are common causes for this to occur.</p>
# <p>To be considered for reinstatement, please contact <a href="mailto:support@ahd.com">support@ahd.com</a> with your IP address (73.174.57.201), the time and date you first received this message, and any explanation you have regarding irregular usage of AHD.com at the time of suspension.</p></div>
# <div align="center" id="footer">
# <table cellpadding="0" cellspacing="0" width="820">
# <tr>
# <td align="left" width="100%">
# <hr color="#D6D6D6" size="1"/>
# <a href="/"><div class="sprite ahdlogoBW_180"></div></a>
# <a href="/about.html">About the company</a>
#                                  |
#                                 <a href="/sitemap.html">Site Map</a>
#                                  |
#                                 Email:
#                                 <a href="mailto:support@ahd.com">support@ahd.com</a>
#                                  |
#                                 <a class="popup" href="/policy_privacy.html">Privacy Policy</a>
#                                  |
#                                 <a href="/media/">Media</a>
# <br/>
#                                 Users should read
#                                 <a href="/agree.html">notice, disclaimer, and agreement</a>
#                                  | <br/>
#                                 Copyright ©2000-2022 American Hospital Directory, Inc. All rights reserved.
#                             </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div id="main_container"> </div>
# <div id="left_outer"> </div>
# <div id="left_inner"> </div>
# <div id="right_outer"> </div>
# <div id="right_inner"> </div>
# </div>
# <script type="text/javascript">
#
# $(document).ready(function () { ahd_init_popup_links();
#     $('.help_ajax').fancybox({
#         scrolling: 'none',
#         type: 'ajax',
#         margin: 10,
#         width: 650,
#         onstart: function() { },
#         titleFormat: function() {
#             var alt_name = $(this.orig).parent().attr('alt');
#             if(alt_name != undefined) {
#                 return "<table id='fancybox-title-float-wrap'><tbody><tr><td id='fancybox-title-float-left' style='padding-left: 10px;'>&nbsp;</td><td id='fancybox-title-float-main'>" + alt_name + "</td><td id='fancybox-title-float-right'>&nbsp;</td></tr></tbody></table>";
#             } else {
#                 return '';
#             }
#         }
#         }); });
#
#
# </script>
# <!-- -->
# </body>
# </html>

# %%
table_info = soup.find(class_ = 'report')
tabledata = [i.get_text().strip() for i in table_info.find_all('td')]
tabledata[0:6]

# %%
rows = []
for i in range(183):
    if i == 0: 
        startIndex = 0
    else:
        startIndex = startIndex+6
    row_i = tabledata[startIndex:startIndex+6]
    rows.append(row_i)

# %%
tableData_Df = pd.DataFrame(rows)
tableData_Df.columns = ['HospitalName', 'City', 'NumberOfStaffedBeds', 'TotalDischarges', 'PatientDays', 'GrossPatientRevenue($000)']
tableData_Df

# %%
# adjust data types
tableData_Df.NumberOfStaffedBeds = tableData_Df.NumberOfStaffedBeds.apply(lambda x: x.replace(',', ''))
tableData_Df.NumberOfStaffedBeds = tableData_Df.NumberOfStaffedBeds.apply(lambda x: int(x))

tableData_Df.TotalDischarges = tableData_Df.TotalDischarges.apply(lambda x: x.replace(',', ''))
tableData_Df.TotalDischarges = tableData_Df.TotalDischarges.apply(lambda x: int(x))

tableData_Df.PatientDays = tableData_Df.PatientDays.apply(lambda x: x.replace(',', ''))
tableData_Df.PatientDays = tableData_Df.PatientDays.apply(lambda x: int(x))

tableData_Df['GrossPatientRevenue($000)'] = tableData_Df['GrossPatientRevenue($000)'].apply(
    lambda x: x.replace(',', '').replace('$', ''))
tableData_Df['GrossPatientRevenue($000)'] = tableData_Df['GrossPatientRevenue($000)'].apply(lambda x: float(x))

# %%
tableData_Df.dtypes

# %%
tableData_Df

# %%
#tableData_Df.to_csv('HospitalData_cityLevel.csv')

# %%
### this code would have extracted the zip codes for every hospital, but the website thinks I'm a bot now...

# zipcode_rows = []
# for i in range(len(table_info.find_all(href=True))):
#     hosp_name = table_info.find_all(href=True)[i].get_text().strip()
#     print(hosp_name)
#     full_tag = table_info.find_all(href=True)[i]
#     url_start = str(full_tag).find('"')+1
#     url_end = str(full_tag).find('">')
#     tag_url = str(full_tag)[url_start:url_end]
#     hosp_url = 'https://www.ahd.com'+tag_url
    
#     # pull zip code from hosp website
#     page = requests.get(hosp_url)
#     soup = BeautifulSoup(page.content, 'html.parser')
#     if soup.find(class_='reporthospname') == None: 
#         print(hosp_name, ' zip code not found, skipping...')
#     else: 
#         hosp_zip = soup.find(class_='reporthospname').get_text().strip().split(' ')[-1][-5:]
#         hosp_row = [hosp_name, hosp_zip]
#         zipcode_rows.append(hosp_row)


#str(table_info.find_all(href=True)[0])[9:81]

# %%
# convert cities to county--mapper
city_to_county = pd.read_csv('city_to_county_PA.csv')
count_county = city_to_county.groupby('ZIP', as_index = False)['COUNTY'].count()
count_county[count_county.COUNTY > 1]

# %%
# import hospital cities df to check: 
hospital_city = pd.read_csv('HospitalData_cityLevel.csv')
hospital_city.shape
# Out:
# (183, 7)
